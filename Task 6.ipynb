# %% [markdown]
# ## The Sparks Foundation
#
# ## Data Science and Bussiness Analytics intern
#
# ### Name - Omprakash Verma
#
# ### Task 6: Prediction using Decision Tree Algorithm

# %%
#importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing the dataset
df= pd.read_csv(r'C:\Users\omprakash\Downloads\iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#checking the shape of dataset
print(df.shape)
# Out:
# (150, 6)

# %%
from sklearn.preprocessing import LabelEncoder

#convert species columns into integer
l = LabelEncoder()
df['Species'] = l.fit_transform(df['Species'])

# %%
#split x and y
x=df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=df[['Species']]
print(x.head())
print(y.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
#split the dataset into train and test sets

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

t = DecisionTreeClassifier()
t.fit(x_train,y_train)

print("Model Score:",t.score(x_test,y_test))
# Out:
# Model Score: 0.9333333333333333

# %%
y_pred = t.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print('Decision matrix')
print(cm)
# Out:
# Decision matrix
# [[10  0  0]
#  [ 0  9  1]
#  [ 0  1  9]]

# %%
#import liberies for graph
import graphviz 
from sklearn import tree

# %%
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa','versicolor','virginica']

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (4,4), dpi = 300)

tree.plot_tree(t, feature_names = fn, class_names = cn, filled = True);
